# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# <b>Paulo Cardoso</b>

# %% [markdown]
# Data Architect

# %% [markdown]
# <i>I am interested in data science because it a modern way to problem solve and also can give an edge on my carrer</i>

# %% [markdown]
# ### My code will demonstrate a simple matematical operation

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# - bulet 1
# - bullet 2
# - bullet 3
#
# ***
#
# [link text](http://https://www.coursera.org/learn/open-source-tools-for-data-science/home/welcome)
